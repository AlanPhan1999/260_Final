# %%
import pandas as pd
import numpy as np
from baseball_scraper import statcast

# %%
data1 = statcast(start_dt = '2020-01-01', end_dt='2021-11-01')
# Out:
# This is a large query, it may take a moment to complete
# Skipping offseason dates
# Completed sub-query from 2021-03-15 to 2021-03-21
# Completed sub-query from 2021-03-22 to 2021-03-27
# Completed sub-query from 2021-03-28 to 2021-04-02
# Completed sub-query from 2021-04-03 to 2021-04-08
# Completed sub-query from 2021-04-09 to 2021-04-14
# Completed sub-query from 2021-04-15 to 2021-04-20
# Completed sub-query from 2021-04-21 to 2021-04-26
# Completed sub-query from 2021-04-27 to 2021-05-02
# Completed sub-query from 2021-05-03 to 2021-05-08
# Completed sub-query from 2021-05-09 to 2021-05-14
# Completed sub-query from 2021-05-15 to 2021-05-20
# Completed sub-query from 2021-05-21 to 2021-05-26
# Completed sub-query from 2021-05-27 to 2021-06-01
# Completed sub-query from 2021-06-02 to 2021-06-07
# Completed sub-query from 2021-06-08 to 2021-06-13
# Completed sub-query from 2021-06-14 to 2021-06-19
# Completed sub-query from 2021-06-20 to 2021-06-25
# ...

# %%
data1.to_pickle('Data/yr1.pkl')

# %%
data2 = statcast(start_dt = '2022-01-01', end_dt='2022-11-01')
# Out:
# This is a large query, it may take a moment to complete
# Completed sub-query from 2022-01-01 to 2022-11-01

# %%
data2.to_pickle('Data/y2.pkl')

# %%
data2 = statcast(start_dt = '2023-01-01', end_dt='2023-12-31')
# Out:
# This is a large query, it may take a moment to complete
# Completed sub-query from 2023-01-01 to 2023-12-31

# %%
data2.to_pickle('data/yr3.pkl')

# %%
data2 = statcast(start_dt = '2024-01-01', end_dt='2024-05-27')
# Out:
# This is a large query, it may take a moment to complete
# Completed sub-query from 2024-01-01 to 2024-05-27

# %%
data2.to_pickle('Data/yr4.pkl')

# %%
data2
# Out:
#        index pitch_type  game_date  release_speed  release_pos_x  \
# 0       1821         FF 2024-05-27           99.0          -1.97
# 1       1882         FF 2024-05-27           98.3          -1.73
# 2       1952         FF 2024-05-27           98.5          -1.54
# 3       2012         FF 2024-05-27           98.4          -1.36
# 4       2041         FF 2024-05-27           97.8          -1.57
# ...      ...        ...        ...            ...            ...
# 24995  24628         FF 2024-05-21           93.3           2.02
# 24996  24705         SI 2024-05-21           92.7           2.16
# 24997  24717         SI 2024-05-21           94.0           2.01
# 24998  24875         SL 2024-05-21           80.3           2.21
# 24999  24966         FF 2024-05-21           92.5           2.04
#
#        release_pos_z      player_name    batter   pitcher     events  ...  \
# 0               5.77   Finnegan, Kyle  672284.0  640448.0  strikeout  ...
# ...
